# %%
from agents import Agent, Runner

agent = Agent(name="Assistant", instructions="You are a helpful assistant")

result = await Runner.run(agent, "Write a haiku about recursion in programming.")
print(result.final_output)

# Code within the code,
# Functions calling themselves,
# Infinite loop's dance.
# Out:
# Code loops on itself,
# A mirror of endless paths—
# Solved within the loop.

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Coco Liu']
values = [3]
color = '#4CAF50'

# Plot
plt.bar(labels, values, color=color)

# Configuration
plt.title('Total Security Incidents Assigned to Coco Liu')
plt.xlabel('Assignee')
plt.ylabel('Number of Security Incidents')

# Display
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Incident Number': ['SIR0222747', 'SIR0222816', 'SIR0222753'],
    'Category': ['Equipment loss', 'Phishing', 'Phishing'],
    'Severity': ['Medium', 'Medium', 'Medium'],
    'State': ['Closed', 'Closed', 'Closed'],
    'Risk Score': [40, 40, 40]
}
df = pd.DataFrame(data)

# Visualization
plt.figure(figsize=(8, 5))
for category in df['Category'].unique():
    filtered_df = df[df['Category'] == category]
    plt.bar(
        filtered_df['Incident Number'],
        filtered_df['Risk Score'],
        label=category
    )

plt.title('Risk Score of Security Incidents Assigned to Coco Liu')
plt.xlabel('Incident Number')
plt.ylabel('Risk Score')
plt.legend(title='Category')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for visualization
categories = ['Equipment loss', 'Phishing']
counts = [1, 2]

# Create bar chart
plt.bar(categories, counts, color=['blue', 'orange'])
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Security Incident Tickets Assigned to Coco Liu (by Category)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

names = ['Coco Liu', 'Rodel Rojos']
states = ['Closed', 'Open', 'Analysis']
data = {
    'Coco Liu': [3, 0, 0],
    'Rodel Rojos': [0, 0, 1]
}

x = np.arange(len(names))
bar_width = 0.25
fig, ax = plt.subplots()

for index, state in enumerate(states):
    ax.bar(x + index * bar_width, [data[name][index] for name in names], bar_width, label=state)

ax.set_xlabel('Assigned Individual')
ax.set_ylabel('Number of Incidents')
ax.set_title('Security Incident Distribution by State and Assigned Individuals')
ax.set_xticks(x + bar_width)
ax.set_xticklabels(names)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
data = {'Coco Liu': 3, 'Rodel Rojos': 1}
assigned_to = list(data.keys())
incident_counts = list(data.values())

# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(assigned_to, incident_counts, color=['blue', 'green'])

# Chart formatting
plt.title('Security Incidents Assigned to Individuals', fontsize=14)
plt.xlabel('Assigned To', fontsize=12)
plt.ylabel('Number of Incidents', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data Preparation
names = ['Coco Liu', 'Rodel Rojos']
incident_counts = [3, 1]

# Plotting
fig, ax = plt.subplots()
ax.bar(names, incident_counts, color=['blue', 'orange'])

# Labels and Title
ax.set_ylabel('Number of Security Incidents')
ax.set_xlabel('Employees')
ax.set_title('Security Incidents Assigned by Employees')

# Show Plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data Preparation
groups = ["UNC6077", "Operation ForumTroll", "Wassonite", "Awaken Likho", "Lifting Zmiy"]
attack_techniques = [9, 0, 2, 0, 0]  # Number of attack techniques
indicators_iocs = [14, 0, 0, 54, 0]  # Indicators of Compromise (IoCs)

# Bar chart plotting
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.4
x = range(len(groups))

# Two bars: attack techniques and IoCs
ax.bar(x, attack_techniques, bar_width, label='Attack Techniques')
ax.bar([i + bar_width for i in x], indicators_iocs, bar_width, label='Indicators of Compromise (IoCs)')

# Configuration
ax.set_xticks([i + bar_width/2 for i in x])
ax.set_xticklabels(groups, rotation=45)
ax.set_ylabel('Count')
ax.set_title('APT Groups: Attack Techniques and IoCs')
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

apt_groups = ["UNC6342", "UNC6340", "Storm-2603", "UNC6337", "UNC6197"]
attack_counts = [5, 4, 6, 7, 3]  # Example data

defense_tactics = ["Masquerading", "File/Path Exclusion", "Obfuscated Files", "Code Signing"]
tactic_counts = [3, 2, 4, 1]  # Example data

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.bar(apt_groups, attack_counts, color='skyblue')
ax.set_title("APT Activities by Groups")
ax.set_xlabel("APT Group")
ax.set_ylabel("Number of Observed Attacks")

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Attack Techniques', 'File-based Indicators']
counts = [9, 8]

# Create bar chart
plt.bar(categories, counts, color=['blue', 'green'])
plt.title('APT Group UNC6077 Analysis Summary')
plt.ylabel('Count')
plt.xlabel('Indicator Type')
plt.show()

# %%
import matplotlib.pyplot as plt

tactics = ["T1027", "T1027.001", "T1036", "T1036.007", "T1036.008", "T1055", "T1547", "T1547.009", "T1560"]
iocs = [14]

plt.figure(figsize=(10, 5))
plt.bar(tactics, [1] * len(tactics), color="blue", label="Attack Techniques")
plt.axhline(y=iocs[0], color="red", label="Total IOCs")
plt.title("UNC6077 Attack Techniques and IOCs")
plt.xlabel("MITRE ATT&CK Techniques")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Files', 'Domains', 'IP Addresses', 'URLs']
values = [8, 2, 2, 2]

# Plot
plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='skyblue')
plt.title('Indicators of Compromise (IoCs) by Type for UNC6077')
plt.xlabel('IoC Type')
plt.ylabel('Count')

# Display
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# Data
timeline_data = {
    'January 2025': ['DDoS Campaigns by Z-Pentest and NoName057(16)', 'Financial Crimes leveraging FAKEUPDATES'],
    'July 2025': ['Exploitation of CVE-2025-53770 targeting SharePoint'],
    '2024': ['Baseline cyber espionage activities targeting telecommunications']
}

# Plot
fig, ax = plt.subplots()
y_pos = range(len(timeline_data))
ax.barh(y_pos, [len(events) for events in timeline_data.values()], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(timeline_data.keys())
ax.set_xlabel('Number of Incidents')
ax.set_title('Timeline of Cyber Threats Targeting Telecommunications')

# Annotate with event details
event_strs = ["\n".join(events) for events in timeline_data.values()]
for i, (y, x, label) in enumerate(zip(y_pos, [len(events) for events in timeline_data.values()], event_strs)):
    ax.text(x + 0.2, i, label, va='center')

plt.show()
